# %% [markdown]
# ## **Bigrams**

# %% [markdown]
# 1. Recreate all the calculations of the previous slides with the same corpus
# 2. Test the LM with some words or phrases
# 3. Try do the
#
# <s>"I am Sam" </s>
# <s>"Sam I am" </s>
# <s>"I do not like eggs and ham"</s>
#
# # P(I|<s>) = 2/3 = .67
# # P(<s>|Sam) = 1/2 = .5
#
# # P(Sam|<s>) = 1/3 = .33
# # P(Sam|am) = 1/2 = .5
#
# # P(am|I) = 2/3 = .67
# # P(do|I) = 1/3 = .33

# %%
corpus = [
    ["<s>","I", "am", "Sam","</s>"],
    ["<s>","Sam", "I", "am", "</s>"],
    ["<s>", "I", "do", "not", "like", "eggs", "and", "ham","</s>"]
]

# %%
word_counts = {}
for sent in corpus:
    prev = None
    for word in sent:
        ...

# %%
def biagram_probability(word1, word2):
    biagram = (word1, word2)
    biagram_count = biagram_counts.get(biagram, 0)
    word1_count = word_counts.get(word1, 0)
    if word_count == 0:
        return 0
    else: 
        ...
